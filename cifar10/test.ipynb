# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 110s 1us/step

# %%
print("Training images shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

plt.figure(figsize=(8,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')
plt.show()

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3,3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))  # 10 classes
# Out:
# C:\Users\debas\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "best_cifar10_model.keras",   # file name
    monitor="val_accuracy",       # watch validation accuracy
    save_best_only=True,          # only save if it improves
    mode="max",                   # higher accuracy is better
    verbose=1
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=10,
    validation_data=(x_test, y_test),
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3534 - loss: 1.7444
# Epoch 1: val_accuracy improved from -inf to 0.53300, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.3535 - loss: 1.7442 - val_accuracy: 0.5330 - val_loss: 1.3169
# Epoch 2/10
# 1560/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5624 - loss: 1.2251
# Epoch 2: val_accuracy improved from 0.53300 to 0.60270, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.5624 - loss: 1.2250 - val_accuracy: 0.6027 - val_loss: 1.1075
# Epoch 3/10
# 1558/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6315 - loss: 1.0467
# Epoch 3: val_accuracy improved from 0.60270 to 0.63330, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6315 - loss: 1.0466 - val_accuracy: 0.6333 - val_loss: 1.0585
# Epoch 4/10
# 1555/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6640 - loss: 0.9466
# Epoch 4: val_accuracy improved from 0.63330 to 0.65610, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.6640 - loss: 0.9466 - val_accuracy: 0.6561 - val_loss: 0.9786
# Epoch 5/10
# 1557/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6989 - loss: 0.8603
# Epoch 5: val_accuracy improved from 0.65610 to 0.68210, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.6989 - loss: 0.8603 - val_accuracy: 0.6821 - val_loss: 0.9126
# Epoch 6/10
# 1559/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7189 - loss: 0.7912
# Epoch 6: val_accuracy improved from 0.68210 to 0.68560, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7189 - loss: 0.7912 - val_accuracy: 0.6856 - val_loss: 0.9080
# Epoch 7/10
# 1558/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7390 - loss: 0.7439
# Epoch 7: val_accuracy did not improve from 0.68560
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7390 - loss: 0.7440 - val_accuracy: 0.6791 - val_loss: 0.9272
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7525 - loss: 0.7016
# Epoch 8: val_accuracy did not improve from 0.68560
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7525 - loss: 0.7016 - val_accuracy: 0.6856 - val_loss: 0.9344
# Epoch 9/10
# 1559/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7669 - loss: 0.6587
# Epoch 9: val_accuracy improved from 0.68560 to 0.71220, saving model to best_cifar10_model.keras
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7669 - loss: 0.6587 - val_accuracy: 0.7122 - val_loss: 0.8644
# Epoch 10/10
# 1558/1563 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7842 - loss: 0.6196
# Epoch 10: val_accuracy did not improve from 0.71220
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7842 - loss: 0.6196 - val_accuracy: 0.6993 - val_loss: 0.9007

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("\nTest accuracy:", test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.6993 - loss: 0.9007
#
# Test accuracy: 0.6992999911308289

# %%
from tensorflow import keras

best_model = keras.models.load_model("best_cifar10_model.keras")

loss, acc = best_model.evaluate(x_test, y_test, verbose=0)

print("Best Saved Model Test Accuracy:", acc)
# Out:
# Best Saved Model Test Accuracy: 0.7121999859809875

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(x_train)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([

    layers.Input(shape=(32,32,3)),

    # Block 1
    layers.Conv2D(32, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),

    # Block 3
    layers.Conv2D(128, (3,3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 30, 30, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 15, 15, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 13, 13, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 289,706 (1.11 MB)
#  Trainable params: 289,002 (1.10 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

checkpoint = ModelCheckpoint(
    "best_cifar10_model_v2.keras",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

# %%
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    epochs=30,
    validation_data=(x_test, y_test),
    callbacks=[checkpoint, reduce_lr, early_stop]
)
# Out:
# Epoch 1/30
#   1/782 ━━━━━━━━━━━━━━━━━━━━ 29:05 2s/step - accuracy: 0.0469 - loss: 3.9481
# C:\Users\debas\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2862 - loss: 2.2426
# Epoch 1: val_accuracy improved from -inf to 0.43650, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 47ms/step - accuracy: 0.2863 - loss: 2.2422 - val_accuracy: 0.4365 - val_loss: 1.5375 - learning_rate: 0.0010
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4882 - loss: 1.4209
# Epoch 2: val_accuracy improved from 0.43650 to 0.49850, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.4882 - loss: 1.4209 - val_accuracy: 0.4985 - val_loss: 1.4020 - learning_rate: 0.0010
# Epoch 3/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5646 - loss: 1.2143
# Epoch 3: val_accuracy improved from 0.49850 to 0.52920, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.5646 - loss: 1.2142 - val_accuracy: 0.5292 - val_loss: 1.3560 - learning_rate: 0.0010
# Epoch 4/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6121 - loss: 1.0950
# Epoch 4: val_accuracy improved from 0.52920 to 0.62490, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.6121 - loss: 1.0950 - val_accuracy: 0.6249 - val_loss: 1.0582 - learning_rate: 0.0010
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6422 - loss: 1.0157
# Epoch 5: val_accuracy improved from 0.62490 to 0.67440, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.6422 - loss: 1.0157 - val_accuracy: 0.6744 - val_loss: 0.9626 - learning_rate: 0.0010
# Epoch 6/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6626 - loss: 0.9634
# Epoch 6: val_accuracy did not improve from 0.67440
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.6626 - loss: 0.9634 - val_accuracy: 0.6631 - val_loss: 0.9708 - learning_rate: 0.0010
# Epoch 7/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6776 - loss: 0.9152
# Epoch 7: val_accuracy improved from 0.67440 to 0.71510, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.6776 - loss: 0.9152 - val_accuracy: 0.7151 - val_loss: 0.8310 - learning_rate: 0.0010
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6902 - loss: 0.8918
# Epoch 8: val_accuracy improved from 0.71510 to 0.71820, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.6902 - loss: 0.8918 - val_accuracy: 0.7182 - val_loss: 0.8292 - learning_rate: 0.0010
# Epoch 9/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7011 - loss: 0.8560
# Epoch 9: val_accuracy improved from 0.71820 to 0.74010, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7011 - loss: 0.8560 - val_accuracy: 0.7401 - val_loss: 0.7589 - learning_rate: 0.0010
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7083 - loss: 0.8395
# Epoch 10: val_accuracy did not improve from 0.74010
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7083 - loss: 0.8395 - val_accuracy: 0.6889 - val_loss: 0.9116 - learning_rate: 0.0010
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7178 - loss: 0.8136
# Epoch 11: val_accuracy improved from 0.74010 to 0.74450, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7178 - loss: 0.8136 - val_accuracy: 0.7445 - val_loss: 0.7375 - learning_rate: 0.0010
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7227 - loss: 0.8062
# Epoch 12: val_accuracy did not improve from 0.74450
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.7227 - loss: 0.8062 - val_accuracy: 0.6960 - val_loss: 0.8870 - learning_rate: 0.0010
# Epoch 13/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7294 - loss: 0.7908
# Epoch 13: val_accuracy improved from 0.74450 to 0.74560, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7294 - loss: 0.7907 - val_accuracy: 0.7456 - val_loss: 0.7370 - learning_rate: 0.0010
# Epoch 14/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7320 - loss: 0.7708
# Epoch 14: val_accuracy did not improve from 0.74560
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7320 - loss: 0.7708 - val_accuracy: 0.7016 - val_loss: 0.8823 - learning_rate: 0.0010
# Epoch 15/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7442 - loss: 0.7543
# Epoch 15: val_accuracy improved from 0.74560 to 0.80000, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.7442 - loss: 0.7543 - val_accuracy: 0.8000 - val_loss: 0.5820 - learning_rate: 0.0010
# Epoch 16/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7430 - loss: 0.7460
# Epoch 16: val_accuracy did not improve from 0.80000
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7430 - loss: 0.7461 - val_accuracy: 0.7694 - val_loss: 0.6704 - learning_rate: 0.0010
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7477 - loss: 0.7368
# Epoch 17: val_accuracy did not improve from 0.80000
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7477 - loss: 0.7368 - val_accuracy: 0.7716 - val_loss: 0.6753 - learning_rate: 0.0010
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7485 - loss: 0.7305
# Epoch 18: val_accuracy did not improve from 0.80000
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7485 - loss: 0.7305 - val_accuracy: 0.7585 - val_loss: 0.7051 - learning_rate: 0.0010
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7609 - loss: 0.6939
# Epoch 19: val_accuracy did not improve from 0.80000
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.7610 - loss: 0.6939 - val_accuracy: 0.7946 - val_loss: 0.6037 - learning_rate: 5.0000e-04
# Epoch 20/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7639 - loss: 0.6812
# Epoch 20: val_accuracy did not improve from 0.80000
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7639 - loss: 0.6812 - val_accuracy: 0.7723 - val_loss: 0.6662 - learning_rate: 5.0000e-04
# Epoch 21/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7709 - loss: 0.6716
# Epoch 21: val_accuracy did not improve from 0.80000
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7709 - loss: 0.6716 - val_accuracy: 0.7816 - val_loss: 0.6410 - learning_rate: 5.0000e-04
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7782 - loss: 0.6448
# Epoch 22: val_accuracy did not improve from 0.80000
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7782 - loss: 0.6448 - val_accuracy: 0.8000 - val_loss: 0.5893 - learning_rate: 2.5000e-04
# Epoch 23/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7798 - loss: 0.6463
# Epoch 23: val_accuracy improved from 0.80000 to 0.80460, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7798 - loss: 0.6463 - val_accuracy: 0.8046 - val_loss: 0.5766 - learning_rate: 2.5000e-04
# Epoch 24/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7807 - loss: 0.6402
# Epoch 24: val_accuracy did not improve from 0.80460
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.7807 - loss: 0.6402 - val_accuracy: 0.7952 - val_loss: 0.6025 - learning_rate: 2.5000e-04
# Epoch 25/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7847 - loss: 0.6294
# Epoch 25: val_accuracy did not improve from 0.80460
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7846 - loss: 0.6294 - val_accuracy: 0.7964 - val_loss: 0.5972 - learning_rate: 2.5000e-04
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7882 - loss: 0.6236
# Epoch 26: val_accuracy improved from 0.80460 to 0.81720, saving model to best_cifar10_model_v2.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7882 - loss: 0.6236 - val_accuracy: 0.8172 - val_loss: 0.5326 - learning_rate: 2.5000e-04
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7833 - loss: 0.6279
# Epoch 27: val_accuracy did not improve from 0.81720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.7833 - loss: 0.6279 - val_accuracy: 0.8062 - val_loss: 0.5638 - learning_rate: 2.5000e-04
# Epoch 28/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7883 - loss: 0.6227
# Epoch 28: val_accuracy did not improve from 0.81720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.7883 - loss: 0.6227 - val_accuracy: 0.7993 - val_loss: 0.5947 - learning_rate: 2.5000e-04
# Epoch 29/30
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7918 - loss: 0.6104
# Epoch 29: val_accuracy did not improve from 0.81720
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.7918 - loss: 0.6104 - val_accuracy: 0.8126 - val_loss: 0.5465 - learning_rate: 2.5000e-04
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7921 - loss: 0.6125
# Epoch 30: val_accuracy did not improve from 0.81720
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 63ms/step - accuracy: 0.7921 - loss: 0.6125 - val_accuracy: 0.8152 - val_loss: 0.5468 - learning_rate: 1.2500e-04

# %%
best_model = keras.models.load_model("best_cifar10_model_v2.keras")
loss, acc = best_model.evaluate(x_test, y_test, verbose=0)

print("Improved Test Accuracy:", acc)
# Out:
# Improved Test Accuracy: 0.8172000050544739

# %%
best_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 30, 30, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 15, 15, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 13, 13, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 867,712 (3.31 MB)
#  Trainable params: 289,002 (1.10 MB)
#  Non-trainable params: 704 (2.75 KB)
#  Optimizer params: 578,006 (2.20 MB)

# %%
loss, acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8174 - loss: 0.5283
# Test Accuracy: 0.8172000050544739
